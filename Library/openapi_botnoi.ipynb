# %%
import requests
def predictgender(keyword):
  url = "https://openapi.botnoi.ai/service-api/bn_nameapi?name="+keyword
  headers = {
      'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..C7qI8BPCxX4-SDoQdwOMSn4luSIEwpBfLeSiZ9bV2MY'
  }
  response = requests.request("GET", url, headers=headers)
  #print(response.text)
  return response.json()

# %%
predictgender("ณเดช")
# Out:
# {'confidence': 0.8902764447790095, 'name': 'ณเดช', 'result': 'ชาย'}
